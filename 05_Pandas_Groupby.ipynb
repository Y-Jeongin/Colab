# %% [markdown]
# <a href="https://colab.research.google.com/github/Y-Jeongin/Colab/blob/main/05_Pandas_Groupby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Groupby : 같은 값을 하나로 묶어 통계 또는 집계 겨로가를 얻기 위한 기능

# %%
df = pd.DataFrame({
    'city' : ['부산', '부산', '부산', '부산', '서울', '서울', '서울'],
    'fruit' : ['apple', 'orange', 'banana', 'banana', 'apple', 'apple', 'banana'],
    'price':[100,200,250,300,150,200,400],
    'quantity':[1,2,3,4,5,6,7]
})
df
# Out:
#   city   fruit  price  quantity
# 0   부산   apple    100         1
# 1   부산  orange    200         2
# 2   부산  banana    250         3
# 3   부산  banana    300         4
# 4   서울   apple    150         5
# 5   서울   apple    200         6
# 6   서울  banana    400         7

# %% [markdown]
# #### get_group() : 그룹 안에 데이터를 확인

# %%
df.groupby('city').mean()
# Out:
# <ipython-input-3-1de92c00fe84>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('city').mean()
#       price  quantity
# city
# 부산    212.5       2.5
# 서울    250.0       6.0

# %%
df.groupby('city').get_group('부산')
# Out:
#   city   fruit  price  quantity
# 0   부산   apple    100         1
# 1   부산  orange    200         2
# 2   부산  banana    250         3
# 3   부산  banana    300         4

# %% [markdown]
# #### size() : 각 그룹의 사이즈 확인

# %%
df.groupby('city').size()
# Out:
# city
# 부산    4
# 서울    3
# dtype: int64

# %%
df.groupby('city').size()['부산']
# Out:
# 4

# %% [markdown]
# #### agg() : Aggreation의 약자

# %%
df.groupby('city').agg(np.mean)
# Out:
# <ipython-input-7-d3e542c46df5>:1: FutureWarning: The operation <function mean at 0x7ce7761183a0> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.
#   df.groupby('city').agg(np.mean)
#       price  quantity
# city
# 부산    212.5       2.5
# 서울    250.0       6.0

# %%
# 가격 평균과 수량은 합계를 동시에 계산
df.groupby('city').agg({'price':'mean', 'quantity':'sum'})
# Out:
#       price  quantity
# city
# 부산    212.5        10
# 서울    250.0        18

# %%
def my_mean(s):
    return np.mean(s)
df.groupby('city').agg({'price':my_mean, 'quantity':sum})
# Out:
#       price  quantity
# city
# 부산    212.5        10
# 서울    250.0        18

# %% [markdown]
# #### 대륙과 국가별 음주 소비량을 분석한 데이터셋
# - 각각의 피처들 간의 상관관계 파악
# - 아프리카와 유럽간의 맥주 소비량 차이 검정

# %%
drinks = pd.read_csv('drinks.csv')
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
# 각 피처들간의 상관관계 파악 - pearson 상관계수
corr = drinks[['beer_servings', 'wine_servings']].corr(method = 'pearson')
print(corr)
# Out:
#                beer_servings  wine_servings
# beer_servings       1.000000       0.527172
# wine_servings       0.527172       1.000000

# %% [markdown]
# ### 여러 피처들 간의 상관관계 분석

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
cols = ['beer_servings', 'spirit_servings', 'wine_servings', 'total_litres_of_pure_alcohol']
corr = drinks[cols].corr(method = 'pearson')
print(corr)
# Out:
#                               beer_servings  spirit_servings  wine_servings  \
# beer_servings                      1.000000         0.458819       0.527172
# spirit_servings                    0.458819         1.000000       0.194797
# wine_servings                      0.527172         0.194797       1.000000
# total_litres_of_pure_alcohol       0.835839         0.654968       0.667598
#
#                               total_litres_of_pure_alcohol
# beer_servings                                     0.835839
# spirit_servings                                   0.654968
# wine_servings                                     0.667598
# total_litres_of_pure_alcohol                      1.000000

# %%
# heatmap으로 시각화

# %%
# 산점도 시각화(sns.pairplot)

# %%
# 대륙(continent)의 결측값을 대체값(OT)으로 채우는 작업
## 결측여부 확인 : isnull().sum()
## 결측값 대체 : fillna(value)
drinks.isnull().sum()

drinks['continent'] = drinks['continent'].fillna('OT')
drinks.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF
# 5                           4.9        OT
# 6                           8.3        SA
# 7                           3.8        EU
# 8                          10.4        OC
# 9                           9.7        EU

# %%
# 대륙별로 맥주 소비량의 최대, 최소, 평균을 추출
res = drinks.groupby('continent').beer_servings.agg(['max', 'min', 'mean'])
res
# Out:
#            max  min        mean
# continent
# AF         376    0   61.471698
# AS         247    0   37.045455
# EU         361    0  193.777778
# OC         306    0   89.687500
# OT         285    1  145.434783
# SA         333   93  175.083333

# %%
# idxmax() : Series 객체에서 가장 값이 큰 index를 반환하는 메서드
# 평균 맥주 소비량이 가장 큰 대륙은?
res = drinks.groupby('continent').beer_servings.mean().idxmax()
res
# Out:
# 'EU'

# %%
# t-tets : 차이 검정
# 아프리카와 유럽 간의 맥주 소비량 차이를 검정
from scipy import stats  # import scipy.stats as stats
africa = drinks[drinks['continent'] == 'AF']
europe = drinks[drinks['continent'] == 'EU']

# %%
# 정규분포 - 정규성
# 임계값 또는 유효범위 0.05
# shapiro test - 정규성 검증, p-value > 0.05
# p-value > 0.05이면 정규분포이다.
# 귀무가설 : 차이가 없다. 일반적인 가설
# 대립가설 : 연구자의 가설, 내가 주장하고 싶은 가설
sha_a, sha_pvalue = stats.shapiro(africa['beer_servings'])
print(sha_a, sha_pvalue)
# Out:
# 0.6982115507125854 3.84315423929138e-09

# %%
# 등분산 : 분산의 동질성 검사, levene test
e, p = stats.levene(africa['beer_servings'], europe['beer_servings'])
print(e, p)

if p > 0.05:
    print('등분산이다.')
else:
    print('등분산이 아니다.')
# Out:
# 6.015144059118397 0.015989187968374834
# 등분산이 아니다.

# %%
# Welch's, Fisher's 검정

# %% [markdown]
# ## 카이제곱 검정(Chi square test)
# - 두 데이터가 통계적으로 같은지 다른지 검정하는 방법
# - 카이제곱 검정에는 두 가지 형태가 있으며, 카이제곱 통계량과 분포를 사용하지만 목적에 따라 달라짐
# - 적합도 검정 : 관찰된 값이 기대값과 같은지 다른지 검정
# - 동질성 검정 : 두 집단의 분포가 동일한지 검정
# - 독립성 검정 : 두 개 이상의 변수가 서로 독립인지 검정

# %%
data1 = [4, 6, 17, 16, 8, 9]
data2 = [10, 10, 10, 10, 10, 10]

# 집단의 대표값
print(np.mean(data1))
print(np.mean(data2))
# Out:
# 10.0
# 10.0

# %%
# 카이제곱 검정 : 두 데이터가 통계적으로 같은지를 검정
chis =stats.chisquare(data1, data2)
chis
# Out:
# Power_divergenceResult(statistic=14.200000000000001, pvalue=0.014387678176921308)

# %% [markdown]
# - 귀무가설 : A = B, p-value > 0.05, 같다.
# - 대립가설 : A ≠ B, p-value < 0.05, 같지않다.

# %% [markdown]
# ## T-검정 : 차이 검정
# 1. 단일 표본 t검정(1개의 그룹) : 연속형 변수를 대상으로
#    - ttest_1samp()
# 2. 독립 표본 t검정(서로 다른 2개의 그룹)
#    - ttest_ind()
# 3. 대응표본 t검정(같은 그룹)
#    - ttest_rel()

# %%
# 단일표본 t검정 : 1개의 그룹
# 일반적으로 청소년의 신장은 175이다.
np.random.seed(100)
# 평균 0, 표준편차 5인 20개의 난수 발생
height = [175 + np.random.normal(0, 5) for a in range(20)]
print(height)
# Out:
# [166.25117263472652, 176.7134020166375, 180.7651790128182, 173.73781981739305, 179.90660393475616, 177.5710942069719, 176.105898346107, 169.64978334715855, 174.05252084588412, 176.2750072213669, 172.70986507248688, 177.17581744061445, 172.0820247483867, 179.08423535842888, 178.3636040285483, 174.47794428304687, 172.34359811574046, 180.14866342566674, 172.8093218864779, 169.4084087687228]

# %%
result = stats.ttest_1samp(height, 175)
print(result)
# Out:
# TtestResult(statistic=-0.020929720802605085, pvalue=0.9835199566394546, df=19)

# %% [markdown]
# - p-value <= 0.05, 대립가설 채택
# - p-value > 0.05, 귀무가설 채택

# %%
# 독립표본 t검정(서로 다른 2개의 집단을 이용)
group1 = [170 + np.random.normal(0, 5) for a in range(20)]
group2 = [175 + np.random.normal(0, 5) for a in range(20)]
print(group1)
print(group2)
# Out:
# [178.0949083033763, 177.70802587256702, 168.74060430393394, 165.7878213087435, 170.9225934528197, 174.68541100554475, 173.65500171917404, 176.80778062572665, 168.3688097039885, 170.27838007427388, 171.11199804277652, 162.7839150238733, 166.21823847202782, 174.08227005509642, 173.7522238076709, 167.72026536266, 175.94811134014563, 161.54691586808198, 163.21800475569344, 163.83782743042536]
# [172.27780419163767, 171.65914131593286, 175.0365728161445, 171.9353063226092, 181.49874037377654, 166.3345218817336, 170.08344950435185, 176.7875387658368, 166.93210748588913, 182.35356933306065, 169.0599120134114, 172.25126903232254, 170.29976919227616, 170.86033817817065, 175.5443173391684, 177.5390479524616, 170.6888632674476, 181.2473487136349, 174.60194377041302, 170.55134259367483]

# %%
# 등분산 가정(분산이 같을 경우)
result1 = stats.ttest_ind(group1, group2)
print(result1)
# Out:
# TtestResult(statistic=-1.9924662346475654, pvalue=0.053539257776348465, df=38.0)

# %%
# 등분산 가정을 하지 않을 경우(분산이 다른 경우)
result2 = stats.ttest_ind(group1, group2, equal_var = False)
print(result2)
# Out:
# TtestResult(statistic=-1.9924662346475654, pvalue=0.05365506048684418, df=37.40586696691316)

# %%
# 대응표본 t검정(같은 그룹을 대상으로, 반드시 샘플데이터의 수가 동일해야 한다.)
before = [60 + np.random.normal(0, 5) for a in range(20)]
print(before)

after = [60 + w * np.random.normal(0.99, 0.02) for w in range(20)]
print(after)
# Out:
# [63.45060735112354, 63.43445033069202, 52.166562352108045, 64.52487060733341, 63.89411199661534, 62.1411643529837, 60.544359949489575, 60.141418174115366, 57.10587087604506, 54.00274400403035, 51.47023997130915, 61.84581978553503, 69.38286713481082, 58.115483249155126, 69.15968040912767, 60.01508717015607, 59.619882671376885, 60.019787969937994, 59.07492944551443, 47.56424232388615]
# [60.0, 60.96727477986345, 61.86106738103796, 62.97199903668833, 63.94008890663535, 64.90498235649883, 65.95589133613785, 66.93310994992551, 67.97077887615058, 68.7745654480095, 69.64072163856997, 70.9109306775844, 71.77830837601358, 72.56164427311842, 73.75767064205054, 74.468693087746, 76.34757470029544, 77.06575282389564, 77.11509075568517, 78.75877550144381]

# %%
res = stats.ttest_rel(before, after)
print(res)
# p-value < 0.05, 대립가설 채택
# p-value >= 0.05, 귀무가설 채택
# Out:
# TtestResult(statistic=-4.799755662672362, pvalue=0.0001245348251710736, df=19)

# %%
# 아프리카와 유럽간의 맥주 소비량 차이를 검정
a = stats.ttest_ind(africa['beer_servings'], europe['beer_servings'])
b = stats.ttest_ind(africa['beer_servings'], europe['beer_servings'], equal_var = False)
print(a)
print(b)
# Out:
# TtestResult(statistic=-7.267986335644365, pvalue=9.719556422442453e-11, df=96.0)
# TtestResult(statistic=-7.143520192189803, pvalue=2.9837787864303205e-10, df=84.40013075489844)

# %%
z
